# %%
import numpy as np
import pandas as pd
us_file_path = "./data/prescript_1195.csv"
_count = pd.read_csv(us_file_path)
print(_count)
# Out:
#                           s                                               h
# 0                     [262]                                  [865,912,1044]
# 1                      [88]            [862,864,865,912,913,1109,1153,1182]
# 2                     [185]                                          [1043]
# 3                      [14]                                       [499,606]
# 4                     [188]                                           [967]
# ...                     ...                                             ...
# 33760         [120,286,306]                     [542,884,908,934,1056,1114]
# 33761                 [229]                         [469,542,827,1119,1145]
# 33762                 [100]             [662,666,713,730,749,967,1030,1148]
# 33763                 [100]  [662,713,749,817,905,1081,1100,1114,1127,1148]
# 33764  [14,120,286,306,314]     [627,831,832,857,908,910,915,936,1049,1119]
#
# [33765 rows x 2 columns]

# %%
pS_list = [[0] * 390 for _ in range(_count)]
pS_array = np.array(pS_list)
print(pS_array)
print(pS_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11180/3453081071.py in <module>
# ----> 1 pS_list = [[0] * 390 for _ in range(_count)]
#       2 pS_array = np.array(pS_list)
#       3 print(pS_array)
#       4 print(pS_list)
#
# TypeError: 'DataFrame' object cannot be interpreted as an integer

# %%
cnt = []
# print(_count.iloc[1,1])
for i in range(_count.shape[0]):
    for j in range(_count.loc[i].shape[0]):
        tmp = _count.iloc[i,j]
        print(np.array(tmp))
print(cnt)
# Out:
# [262]
# [865,912,1044]
# [88]
# [862,864,865,912,913,1109,1153,1182]
# [185]
# [1043]
# [14]
# [499,606]
# [188]
# [967]
# [151,375]
# [1167]
# [106]
# [436,831,1013]
# [377]
# [538,901]
# [266]
# [891,987,995,1049]
# [369]
# [569,853,958,987,1049]
# [106]
# [436,831,1013]
# [222,276,346]
# [427,436,805,862,865,868,912,947]
# [348]
# [427,436,686,824,873,986]
# [217]
# [862,978,1165]
# [369]
# [862,979,1044,1147]
# [367]
# [1044,1191]
# [348]
# [953,994]
# [348]
# [907,953,1095,1100]
# [348]
# [907,1023,1067]
# [362]
# [864,1044]
# [362]
# [1174]
# [10]
# [953,954]
# [349]
# [908,915,1049,1078,1159]
# [237]
# [469,486,832,839,857,867,882,893,897,1027,1028,1108,1113,1135]
# [266]
# [656,880,1039,1045,1047,1049,1056]
# [330]
# [794,832,867,880,884,897,898,964,995,1048,1119]
# [222]
# [479,792,794,884,964,1030]
# [120,328]
# [934,935,936,938]
# [348]
# [491,817,831,832,897,906,907,987,1049,1067,1095]
# [348]
# [907,1023,1067]
# [363]
# [994,1056]
# [210]
# [869]
# [217,367]
# ...
